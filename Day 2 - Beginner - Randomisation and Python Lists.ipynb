# %% [markdown]
# # Code Challenge 1: Heads or Tails

# %% [markdown]
# You are going to write a virtual coin toss program. It will randomly tell the user "Heads" or "Tails".
#
# **Important**, the first letter should be capitalised and spelt exactly like in the example e.g. Heads, not heads.
#
# There are many ways of doing this. But to practice what we learnt in the last lesson, you should generate a random number, either 0 or 1. Then use that number to print out Heads or Tails.
#
# e.g.
# 1 means Heads
# 0 means Tails
#
# # Example Output
#
# ```
# Heads
# ```
#
# or
#
# ```
# Tails
# ```

# %%
import random

heads_tails = random.randint(0,1)
if heads_tails == 1:
    print('Heads')
else:
    print('Tails')
# Out:
# Heads

# %% [markdown]
# # Code Challenge 2: Oscar Nominations  - Oscar for best Actor goes to?

# %% [markdown]
# You are going to write a program which will select a random name from a list of names. The person selected will get oscar.
#
# **Important**: You are not allowed to use the `choice()` function.
#
# **Line 8** splits the string `names_string` into individual names and puts them inside a **List** called `names`. For this to work, you must enter all the names as name followed by comma then space. e.g. name, name, name
#
# # Example Input
#
# ```
# JohnnyDepp, JackNickolson, LeonardoDiCaprio, AlPacino, TomHanks, RobertDiNero, DanielDayLewis
# ```
# Note: notice that there is a space between the comma and the next name.
# # Example Output
#
# ```
# And the oscar goes to JohnnyDepp
# ```
#
#
# # Hint
#
# 1. You might need the help of the `len()` function.

# %%
# Split string method
names_string = input("And the Nomminee for best actor in lead roles are. ")
names = names_string.split(", ")
print(names)
oscar = random.randint(0,len(names))
if oscar == 0:
    print('And the Oscar goes to: ',names[0])
elif oscar == 1:
    print('And the Oscar goes to: ',names[1])
elif oscar == 2:
    print('And the Oscar goes to: ',names[2])
elif oscar == 3:
    print('And the Oscar goes to: ',names[3])
elif oscar == 4:
    print('And the Oscar goes to: ',names[4])
elif oscar == 5:
    print('And the Oscar goes to: ',names[5])
else:
    print('And the Oscar goes to: ',names[6])
# Out:
# And the Nomminee for best actor in lead roles are. JohnnyDepp, JackNickolson, LeonardoDiCaprio, AlPacino, TomHanks, RobertDiNero, DanielDayLewis
# ['JohnnyDepp', 'JackNickolson', 'LeonardoDiCaprio', 'AlPacino', 'TomHanks', 'RobertDiNero', 'DanielDayLewis']
# And the Oscar goes to:  AlPacino

# %% [markdown]
# # Code Challenge 3: Treasure Map Exercise

# %% [markdown]
# You are going to write a program which will mark a spot with an X.
#
# In the starting code, you will find a variable called ```map```.
#
# This ```map``` contains a nested list.
# When ```map``` is printed this is what the nested list looks like:
# ```
# ['⬜️', '⬜️', '⬜️'],['⬜️', '⬜️', '⬜️'],['⬜️', '⬜️', '⬜️']
# ```
# In the starting code, we have used new lines (```\n```) to format the three rows into a square, like this:
# ```
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ```
# This is to try and simulate the coordinates on a real map.
#
# ![](https://res.cloudinary.com/dk-find-out/image/upload/q_80,w_1440,f_auto/Co-ordinates_oggjzg.jpg)
#
# Your job is to write a program that allows you to mark a square on the map using a two-digit system. The first digit is the vertical column number and the second digit is the horizontal row number. e.g.:
#
# ![](https://cdn.fs.teachablecdn.com/2vnboIYTFFruvl9FJ2w5)
#
# First your program must take the user input and convert it to a usable format.
#
# Next, you need to use it to update your nested list with an "x".
#
# # Example Input 1
#
# column 2, row 3 would be entered as:
#
# ```
# 23
# ```
#
# # Example Output 1
#
# ```
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', 'X', '⬜️']
# ```
#
# # Example Input 2
#
# column 3, row 1 would be entered as:
#
# ```
# 31
# ```
#
# # Example Output 2
#
# ```
# ['⬜️', '⬜️', 'X']
#
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', '⬜️', '⬜️']
# ```
#
# e.g. When you hit **run**, this is what should happen:
#
# ![](https://cdn.fs.teachablecdn.com/5hliFjyIR96LdestyfPd)
#
# # Hint
#
# 1. Remember that Lists start at index 0!
# 2. ```map``` is just a variable that contains a nested list. It's not related to the map function in Python.

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

#Write your code below this row 👇
horizontal = int(position[0])
vertical = int(position[1])

map[vertical - 1][horizontal - 1] = "X"

# your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# Where do you want to put the treasure? 23
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', 'X', '⬜️']

# %% [markdown]
# # Day 4 : Project Rock Paper Scissors

# %%
user = ['''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___),ROCK
''', '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________),PAPER
''', '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___),SCISSORS
''']

pc = ['''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___),ROCK
''', '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________),PAPER
''', '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___),SCISSORS
''']



lists = (len(user)-1)
#print(lists)


input_game = int(input("Enter number rock = 0 , paper= 1, scisor = 2 : "))
computer = random.randint(0,len(pc)-1)
if input_game == 0:
    print("You Choose:")
    
    print(user[0])
    if computer == 0:
        print("Computer choose:")
        
        print(pc[0])
        if input_game == 0 and computer == 0:
            print("Tie")
    elif computer == 1:
        print("Computer choose:")
        
        print(pc[1])
        if input_game == 0 and computer == 1:
            print("You Loose")
    else:
        print("Computer choose:")
        print(pc[2])
        if input_game == 0 and computer == 2:
            print("You Win")

    
elif input_game == 1:
    print("You Choose:")
    
    print(user[1])
    if computer == 0:
        print("Computer choose:")
        
        print(pc[0])
        if input_game == 1 and computer == 0:
            print("You win")
    elif computer == 1:
        print("Computer choose:")
        
        print(pc[1])
        if input_game == 1 and computer == 1:
            print("Tie")
    else:
        print("Computer choose:")
        
        print(pc[2])
        if input_game == 1 and computer == 2:
            print("You Loose")

    
else:
    print("You Choose:")
    
    print(user[2])
    
    if computer == 0:
        print("Computer choose:")
        
        print(pc[0])
        if input_game == 2 and computer == 0:
            print("You Loose")
    elif computer == 1:
        print("Computer choose:")
        
        print(pc[1])
        if input_game == 2 and computer == 1:
            print("You win")
    else:
        print("Computer choose:")
        
        print(pc[2])
        if input_game == 2 and computer == 2:
            print("Tie")
# Out:
# Enter number rock = 0 , paper= 1, scisor = 2 : 1
# You Choose:
#
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________),PAPER
#
# Computer choose:
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___),ROCK
#
# You win
